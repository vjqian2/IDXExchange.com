# %% [markdown]
# # Monthly Data Aggregation

# %% [markdown]
# ## Data for property sold

# %%
import pandas as pd

sold1 = pd.read_csv("CRMLSSold202401.csv")
sold1
sold2 = pd.read_csv("CRMLSSold202402.csv")
sold2
sold3 = pd.read_csv("CRMLSSold202403.csv")
sold3
sold4 = pd.read_csv("CRMLSSold202404.csv")
sold4
sold5 = pd.read_csv("CRMLSSold202405_filled.csv")
sold5
sold6 = pd.read_csv("CRMLSSold202406_filled.csv")
sold6
sold7 = pd.read_csv("CRMLSSold202407_filled.csv")
sold7
sold8 = pd.read_csv("CRMLSSold202404.csv")
sold8
sold9 = pd.read_csv("CRMLSSold202409.csv")
sold9
sold10 = pd.read_csv("CRMLSSold202410.csv")
sold10
sold11 = pd.read_csv("CRMLSSold202411.csv")
sold11
sold12 = pd.read_csv("CRMLSSold202412.csv")
sold12
sold13 = pd.read_csv("CRMLSSold202501_filled.csv")
sold13
sold14 = pd.read_csv("CRMLSSold202502.csv")
sold14
sold15 = pd.read_csv("CRMLSSold202503.csv")
sold15
sold16 = pd.read_csv("CRMLSSold202504.csv")
sold16
sold17 = pd.read_csv("CRMLSSold202505.csv")
sold17
sold18 = pd.read_csv("CRMLSSold202506.csv")
sold18
sold19 = pd.read_csv("CRMLSSold202507.csv")
sold19
sold20 = pd.read_csv("CRMLSSold202508.csv")
sold20
sold21 = pd.read_csv("CRMLSSold202509.csv")
sold21
sold22 = pd.read_csv("CRMLSSold202510.csv")
sold22
sold23 = pd.read_csv("CRMLSSold202511.csv")
sold23
sold24 = pd.read_csv("CRMLSSold202512.csv")
sold24
sold25 = pd.read_csv("CRMLSSold202601.csv")
sold25
sold26 = pd.read_csv("CRMLSSold202602.csv")
sold26
sold27 = pd.read_csv("CRMLSSold202603.csv")
sold28 = pd.read_csv("CRMLSSold202604.csv")
sold28
sold29 = pd.read_csv("CRMLSSold202605.csv")
sold29
sold30 = pd.read_csv("CRMLSSold202606.csv")
sold30
# Out:
# /var/folders/gn/t0769g993173xwvtkqwcs0z80000gn/T/ipykernel_33886/207672960.py:9: DtypeWarning: Columns (2,36,39,56,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   sold4 = pd.read_csv("CRMLSSold202404.csv")
# /var/folders/gn/t0769g993173xwvtkqwcs0z80000gn/T/ipykernel_33886/207672960.py:17: DtypeWarning: Columns (2,36,39,56,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   sold8 = pd.read_csv("CRMLSSold202404.csv")
# /var/folders/gn/t0769g993173xwvtkqwcs0z80000gn/T/ipykernel_33886/207672960.py:37: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   sold18 = pd.read_csv("CRMLSSold202506.csv")
# /var/folders/gn/t0769g993173xwvtkqwcs0z80000gn/T/ipykernel_33886/207672960.py:51: DtypeWarning: Columns (4,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   sold25 = pd.read_csv("CRMLSSold202601.csv")
# ...

# %%
# Total sold rows before concatenation
before_sold = sum([
    len(sold1), len(sold2), len(sold3), len(sold4), len(sold5),
    len(sold6), len(sold7), len(sold8), len(sold9), len(sold10),
    len(sold11), len(sold12), len(sold13), len(sold14), len(sold15),
    len(sold16), len(sold17), len(sold18), len(sold19), len(sold20),
    len(sold21), len(sold22), len(sold23), len(sold24), len(sold25),
    len(sold26), len(sold27), len(sold28)
])


print("Rows sold before concatenation:", before_sold)
# Out:
# Rows sold before concatenation: 615807

# %%
#row count after concatenation for sold
after_sold = pd.concat([sold1, sold2,sold3, sold4,sold5, sold6,sold7, sold8,sold9, sold10,sold11, sold12,sold13, sold14,sold15, sold16,sold17, sold18,sold19, sold20,sold21, sold22,sold23, sold24,sold25, sold26,sold27, sold28])
print("Rows sold after concatenation:", len(after_sold))
after_sold
# Out:
# Rows sold after concatenation: 615807
#                   BuyerAgentAOR              ListAgentAOR          Flooring  \
# 0                   Mlslistings               Mlslistings  Carpet,Tile,Wood
# 1                    HighDesert                HighDesert               NaN
# 2                  OrangeCounty              OrangeCounty               NaN
# 3                 InlandValleys             InlandValleys               NaN
# 4      SouthwestRiversideCounty  SouthwestRiversideCounty               NaN
# ...                         ...                       ...               ...
# 24256         SierraNorthValley         SierraNorthValley               NaN
# 24257  SouthwestRiversideCounty             InlandValleys               NaN
# 24258                     Mrmls                 Southland               NaN
# 24259              OrangeCounty                HighDesert               NaN
# 24260              CitrusValley              CitrusValley               NaN
#
# ...

# %% [markdown]
# The number of rows are same before and after concatenation

# %%
## Number of rows before Residential filter for sold

print("number sold before residential filter:", len(after_sold))
# Out:
# number sold before residential filter: 615807

# %%
## Number of rows after Residential filter for sold
Residential_sold = after_sold[after_sold["PropertyType"] == "Residential" ]
Residential_sold
print("number sold after residential filter:", len(Residential_sold))
# Out:
# number sold after residential filter: 414567

# %% [markdown]
# ## Data for property listed

# %% [markdown]
# All the listing dates

# %%
list3 = pd.read_csv("CRMLSListing202403.csv")
list3
list4 = pd.read_csv("CRMLSListing202404.csv")
list5 = pd.read_csv("CRMLSListing202405.csv")
list6 = pd.read_csv("CRMLSListing202406.csv")
list7 = pd.read_csv("CRMLSListing202407.csv")
list8 = pd.read_csv("CRMLSListing202408.csv")
list9 = pd.read_csv("CRMLSListing202409.csv")
list10 = pd.read_csv("CRMLSListing202410.csv")
list11 = pd.read_csv("CRMLSListing202411.csv")
list12 = pd.read_csv("CRMLSListing202412.csv")
list13 = pd.read_csv("CRMLSListing202501.csv")
list14 = pd.read_csv("CRMLSListing202502.csv")
list15 = pd.read_csv("CRMLSListing202503.csv")
list16 = pd.read_csv("CRMLSListing202504.csv")
list17 = pd.read_csv("CRMLSListing202505.csv")
list18 = pd.read_csv("CRMLSListing202506.csv")
list19 = pd.read_csv("CRMLSListing202507.csv")
list20 = pd.read_csv("CRMLSListing202508.csv")
list21 = pd.read_csv("CRMLSListing202509.csv")
list22 = pd.read_csv("CRMLSListing202510.csv")
list23 = pd.read_csv("CRMLSListing202511.csv")
list24 = pd.read_csv("CRMLSListing202512.csv")
list25 = pd.read_csv("CRMLSListing202601.csv")
list26 = pd.read_csv("CRMLSListing202602.csv")
list27 = pd.read_csv("CRMLSListing202603.csv")
list28 = pd.read_csv("CRMLSListing202604.csv")
list28
list29 = pd.read_csv("CRMLSListing202605.csv")
list29
list30 = pd.read_csv("CRMLSListing202606.csv")
# Out:
# /var/folders/gn/t0769g993173xwvtkqwcs0z80000gn/T/ipykernel_33886/719758054.py:25: DtypeWarning: Columns (32,58,63,66) have mixed types. Specify dtype option on import or set low_memory=False.
#   list26 = pd.read_csv("CRMLSListing202602.csv")
# /var/folders/gn/t0769g993173xwvtkqwcs0z80000gn/T/ipykernel_33886/719758054.py:29: DtypeWarning: Columns (0,1,3,6,7,10,11,12,22,24,25,27,34,37,40,41,42,43,45,47,48,49,51,52,56,58,59,61,64,70,71,73,77,78,79) have mixed types. Specify dtype option on import or set low_memory=False.
#   list29 = pd.read_csv("CRMLSListing202605.csv")
# /var/folders/gn/t0769g993173xwvtkqwcs0z80000gn/T/ipykernel_33886/719758054.py:31: DtypeWarning: Columns (0,1,3,6,7,10,11,12,22,24,25,27,34,37,40,41,42,43,45,47,48,49,51,52,56,58,59,61,64,70,71,73,77,78,79) have mixed types. Specify dtype option on import or set low_memory=False.
#   list30 = pd.read_csv("CRMLSListing202606.csv")

# %%
# Total rows listed before concatenation
before_list = sum([
    len(list3), len(list4), len(list5), len(list6), len(list7),
    len(list8), len(list9), len(list10), len(list11), len(list12),
    len(list13), len(list14), len(list15), len(list16), len(list17),
    len(list18), len(list19), len(list20), len(list21), len(list22),
    len(list23), len(list24), len(list25), len(list26), len(list28),
])


print("Rows listed before concatenation:", before_list)
# Out:
# Rows listed before concatenation: 766844

# %%
# Total rows listed after concatenation
after_listing = pd.concat([
    list3, list4, list5, list6, list7, list8, list9, list10,
    list11, list12, list13, list14, list15, list16, list17,
    list18, list19, list20, list21, list22, list23, list24,
    list25, list26, list27, list28
], ignore_index=True)

print("Number of rows after concatenation:", len(after_listing))
after_listing
# Out:
# Number of rows after concatenation: 805997
#         OriginalListPrice  ListingKey                ListAgentEmail  \
# 0                  2199.0   446830487              byui@pacbell.net
# 1               3550000.0  1075011892      jasmineguo@firstteam.com
# 2               1599000.0  1075010394                EK@ITZSOLD.COM
# 3                724999.0  1075001993    greg@sandiegodreamteam.com
# 4                825000.0  1075001860               mikeaon@cox.net
# ...                   ...         ...                           ...
# 805992          1375000.0  1151355330       ammarkosgroup@gmail.com
# 805993           985000.0  1149517845          aisaethan@icloud.com
# 805994           450000.0  1147219386  nathaly@shoppingsdhouses.com
# 805995           249000.0  1145273331      BillSoCalCoast@gmail.com
# 805996          1056400.0  1144232364       brokerosborne@gmail.com
#
#          CloseDate  ClosePrice ListAgentFirstName ListAgentLastName  \
# ...

# %%
# number of rows of listed property before residentual filter
print("number listed before residential filter:", len(after_listing))
# Out:
# number listed before residential filter: 805997

# %%
# number of rows of listed property after residentual filter
Residential_list = after_listing[after_listing["PropertyType"] == "Residential" ]
Residential_list
print("number listed after residential filter:", len(Residential_list))
# Out:
# number listed after residential filter: 512665

# %%
Residential_list.to_csv("Residential_list.csv", index=False)

Residential_sold.to_csv("Residential_sold.csv", index=False)

# %% [markdown]
# # Week 2 IDX

# %%
# inspect structure
after_sold.columns
# Out:
# Index(['BuyerAgentAOR', 'ListAgentAOR', 'Flooring', 'ViewYN', 'WaterfrontYN',
#        'BasementYN', 'PoolPrivateYN', 'OriginalListPrice', 'ListingKey',
#        'ListAgentEmail', 'CloseDate', 'ClosePrice', 'ListAgentFirstName',
#        'ListAgentLastName', 'Latitude', 'Longitude', 'UnparsedAddress',
#        'PropertyType', 'LivingArea', 'ListPrice', 'DaysOnMarket',
#        'ListOfficeName', 'BuyerOfficeName', 'CoListOfficeName',
#        'ListAgentFullName', 'CoListAgentFirstName', 'CoListAgentLastName',
#        'BuyerAgentMlsId', 'BuyerAgentFirstName', 'BuyerAgentLastName',
#        'FireplacesTotal', 'AssociationFeeFrequency', 'AboveGradeFinishedArea',
#        'ListingKeyNumeric', 'MLSAreaMajor', 'TaxAnnualAmount',
#        'CountyOrParish', 'MlsStatus', 'ElementarySchool', 'AttachedGarageYN',
#        'ParkingTotal', 'BuilderName', 'PropertySubType', 'LotSizeAcres',
#        'SubdivisionName', 'BuyerOfficeAOR', 'YearBuilt', 'StreetNumberNumeric',
# ...

# %%
after_sold.head()
# Out:
#               BuyerAgentAOR              ListAgentAOR          Flooring  \
# 0               Mlslistings               Mlslistings  Carpet,Tile,Wood
# 1                HighDesert                HighDesert               NaN
# 2              OrangeCounty              OrangeCounty               NaN
# 3             InlandValleys             InlandValleys               NaN
# 4  SouthwestRiversideCounty  SouthwestRiversideCounty               NaN
#
#   ViewYN WaterfrontYN BasementYN PoolPrivateYN  OriginalListPrice  ListingKey  \
# 0   True          NaN        NaN         False           499000.0   551985747
# 1    NaN          NaN        NaN           NaN                0.0   535486633
# 2   True          NaN        NaN           NaN            75000.0   529986282
# 3   True          NaN        NaN           NaN           199000.0   529618166
# 4   True          NaN        NaN           NaN            19500.0   522614340
#
# ...

# %%
after_sold.head(10)
# Out:
#               BuyerAgentAOR              ListAgentAOR              Flooring  \
# 0               Mlslistings               Mlslistings      Carpet,Tile,Wood
# 1                HighDesert                HighDesert                   NaN
# 2              OrangeCounty              OrangeCounty                   NaN
# 3             InlandValleys             InlandValleys                   NaN
# 4  SouthwestRiversideCounty  SouthwestRiversideCounty                   NaN
# 5                  SanDiego                  SanDiego                   NaN
# 6                  SanDiego                  SanDiego  Carpet,Laminate,Tile
# 7                    Laguna                    Laguna           Carpet,Tile
# 8                HighDesert                HighDesert                   NaN
# 9                  SanDiego                  SanDiego                   NaN
#
#   ViewYN WaterfrontYN BasementYN PoolPrivateYN  OriginalListPrice  ListingKey  \
# ...

# %%
# Check property categories
after_sold['PropertyType'].unique()
# Out:
# array(['Residential', 'CommercialLease', 'Land', 'ResidentialLease',
#        'ManufacturedInPark', 'ResidentialIncome', 'CommercialSale',
#        'BusinessOpportunity'], dtype=object)

# %%
# Filter residential
after_sold = after_sold[after_sold.PropertyType == 'Residential']
after_sold
# Out:
#           BuyerAgentAOR      ListAgentAOR          Flooring ViewYN  \
# 0           Mlslistings       Mlslistings  Carpet,Tile,Wood   True
# 5              SanDiego          SanDiego               NaN  False
# 9              SanDiego          SanDiego               NaN  False
# 28          Mlslistings       Mlslistings               NaN  False
# 29            Southland         Southland               NaN  False
# ...                 ...               ...               ...    ...
# 24229        LakeCounty        LakeCounty               NaN   True
# 24231  TheInlandGateway  TheInlandGateway  Carpet,Tile,Wood  False
# 24234          SanDiego       TriCounties             Vinyl   True
# 24235             Mrmls      OrangeCounty               NaN   True
# 24242         Southland       PacificWest      Carpet,Vinyl  False
#
#       WaterfrontYN BasementYN PoolPrivateYN  OriginalListPrice  ListingKey  \
# 0              NaN        NaN         False           499000.0   551985747
# ...
